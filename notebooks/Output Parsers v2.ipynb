# %%
# %load_ext dotenv
# %dotenv

# %%
from langchain_openai.chat_models import ChatOpenAI
from langchain_core.messages import HumanMessage
from langchain_core.output_parsers import StrOutputParser
from langchain_core.output_parsers import CommaSeparatedListOutputParser

# %%
chat = ChatOpenAI(model_name = 'gpt-4', seed = 365, temperature = 0, max_tokens = 100)

# %%
message_human = HumanMessage(content = f'''I've recently adopted a dog. Could you suggest some dog names?
                            {CommaSeparatedListOutputParser().get_format_instructions()}
                            ''')

# %%
print(message_human.content)
# Out:
# I've recently adopted a dog. Could you suggest some dog names?
#                             Your response should be a list of comma separated values, eg: `foo, bar, baz` or `foo,bar,baz`

# %%
response = chat.invoke([message_human])

# %%
print(response.content)
# Out:
# Buddy, Max, Bella, Daisy, Luna, Rocky, Charlie, Coco, Bailey, Molly, Sadie, Toby, Jack, Lucy, Duke, Ruby, Oliver, Lola, Zeus, Stella

# %%
list_output_parser = CommaSeparatedListOutputParser()

# %%
response = chat.invoke([message_human])

# %%
print(response.content)
# Out:
# Buddy, Max, Bella, Daisy, Luna, Rocky, Charlie, Coco, Bailey, Molly, Sadie, Toby, Jack, Lola, Duke, Stella, Oliver, Ruby, Lucy, Cooper

# %%
list_output_parser = CommaSeparatedListOutputParser()

# %%
response_parsed = list_output_parser.invoke(response)

# %%
print(response_parsed)
# Out:
# ['Buddy', 'Max', 'Bella', 'Daisy', 'Luna', 'Rocky', 'Charlie', 'Coco', 'Bailey', 'Molly', 'Sadie', 'Toby', 'Jack', 'Lola', 'Duke', 'Stella', 'Oliver', 'Ruby', 'Lucy', 'Cooper']

# %%
print(list_output_parser.get_format_instructions())
# Out:
# Your response should be a list of comma separated values, eg: `foo, bar, baz` or `foo,bar,baz`
